# %% [markdown]
# # Introduction to Python
#
# Content adopted from [Pierian Data](https://github.com/Pierian-Data/Complete-Python-3-Bootcamp)

# %% [markdown]
# # What is Python and why use it
#
# - **high-level**,
# - **interpreted**,
# - **general-purpose** programming language that is used for a wide range of applications.
# - It is **easy to learn**, and
# - **powerful**.

# %% [markdown]
# # Why is it called Python?
#
# When he began implementing Python, Guido van Rossum was also reading the published scripts from “Monty Python's Flying Circus”, a BBC comedy series from the 1970s. Van Rossum thought he needed a name that was short, unique, and slightly mysterious, so he decided to call the language Python. <sub>--General Python FAQ</sub>

# %%
from IPython.display import display, Image
display(Image(filename="images/python.png"))

# %% [markdown]
# # JupyterLab Desktop
# Homepage: https://github.com/jupyterlab/jupyterlab-desktop

# %%
display(Image(url="https://raw.githubusercontent.com/jupyterlab/jupyterlab-desktop/master/media/jupyterlab-desktop.png"))
# Out:
# <img src="https://raw.githubusercontent.com/jupyterlab/jupyterlab-desktop/master/media/jupyterlab-desktop.png"/>

# %% [markdown]
# # First Things First
#
# As with any programming course, here is the `Hello World!` in Python.

# %%
print ("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # Variable
#
# A variable is a named storage location used to hold a value. The value of a variable can be changed and it can be used in expressions and operations

# %% [markdown]
# # Variable Assignment
#
# - names can not start with a number
# - names can not contain spaces, use _ intead
# - names can not contain any of these symbols: `'",<>/?|\!@#%^&*~-+`
# - accoding to Style Guide for Python Code ([PEP8](https://www.python.org/dev/peps/pep-0008/#function-and-variable-names)), it's considered best practice that names are lowercase with underscores
# - avoid using Python built-in keywords like `list` and `str`
# - avoid using the single characters `l` (lowercase letter el), `O` (uppercase letter oh) and `I` (uppercase letter eye) as they can be confused with 1 and 0

# %% [markdown]
# # Dynamic Typing
#
# Python uses *dynamic typing*, meaning you can reassign variables to different data types. This makes Python very flexible in assigning data types; it differs from other languages that are statically typed.

# %%
my_cat = 2
my_cat
# Out:
# 2

# %%
my_cat = ['Basbousa', 'Lucy']
my_cat
# Out:
# ['Basbousa', 'Lucy']

# %% [markdown]
# # Pros and Cons of Dynamic Typing
# - Pros of Dynamic Typing
#     - very easy to work with
#     - faster development time
# - Cons of Dynamic Typing
#     - may result in unexpected bugs!

# %% [markdown]
# # Assigning Variables
# Variable assignment follows `name = object`, where a single equals sign `=` is an assignment operator

# %%
a = 5
a
# Out:
# 5

# %% [markdown]
# # Reassigning Variables
# Python lets you reassign variables with a reference to the same object.

# %%
a = a + 10
a
# Out:
# 15

# %% [markdown]
# There's actually a shortcut for this. Python lets you add, subtract, multiply and divide numbers with reassignment using `+=`, `-=`, `*=`, and `/=`.

# %%
a += 10
a
# Out:
# 25

# %%
a *= 2
a
# Out:
# 50

# %% [markdown]
# # Determining variable type with `type()`
# You can check what type of object is assigned to a variable using Python's built-in type() function. Common data types include:

# %%
type(a)
# Out:
# int

# %% [markdown]
# # Numbers
# Basically there are two types of numbers:
# - 2 is interger `int`
# - 2.0 is floating point `float`
#
# | Example | Number Type |
# | - | - |
# | 1,2,-5,1000 | Integers |
# | 1.2,-0.5,2e2,3E2 | Floating point |

# %%
type(2)
# Out:
# int

# %%
type(2.0)
# Out:
# float

# %% [markdown]
# Basic Arithmetic 1/2

# %%
2+1 # Addition
# Out:
# 3

# %%
2-1 # Subtraction
# Out:
# 1

# %%
2*2 # Multiplication
# Out:
# 4

# %%
3/2 # Division
# Out:
# 1.5

# %% [markdown]
# Basic Arithmetic 2/2

# %%
3//2 # Floor division (It returns the result of division rounded down to the nearest integer)
# Out:
# 1

# %%
2**3 # Powers
# Out:
# 8

# %% [markdown]
# Question: how to calculate the sequare root of 16?

# %% [markdown]
# # Order of Operations

# %%
2 + 10 * 10 + 3
# Out:
# 105

# %%
(2+10) * (10+3)
# Out:
# 156

# %% [markdown]
# # Strings
#
# Strings in Python are **text**, such as names, stored as a sequence or a list of characters. For example, Python understands the string `'AUC'` to be a sequence of letters in a specific order. This means we will be able to use indexing to grab particular letters (like the first letter `A`, or the last letter `C`).

# %% [markdown]
# # Creating a String
#
# To create a string in Python you need to use either single quotes `'` or double quotes `"`.

# %%
'Hello'
# Out:
# 'Hello'

# %%
'Hello World!'
# Out:
# 'Hello World!'

# %%
"This is also a string"
# Out:
# 'This is also a string'

# %%
'I'm using single quotes, but this will create an error'
# Out:
#   Cell In[24], line 1
#     'I'm using single quotes, but this will create an error'
#        ^
# SyntaxError: invalid syntax

# %%
'Now I\'m ready to use the single quotes inside a string!' # Using escape character
# Out:
# "Now I'm ready to use the single quotes inside a string!"

# %%
"Now I'm ready to use the single quotes inside a string!" # Using double quotes
# Out:
# "Now I'm ready to use the single quotes inside a string!"

# %% [markdown]
# # Printing a String
#
# Using Jupyter notebook with just a string in a cell will automatically output strings, but the correct way to display strings in your output is by using a `print` function.

# %%
'Hello World'
# Out:
# 'Hello World'

# %%
'Hello World 1'
'Hello World 2'
# Out:
# 'Hello World 2'

# %%
print('Hello World 1')
print('Hello World 2')
# Out:
# Hello World 1
# Hello World 2

# %%
print('Hello World 1\nHello World 2') # using \n for new line
# Out:
# Hello World 1
# Hello World 2

# %% [markdown]
# # String Indexing 1/3
#
# Since strings are a sequence, we can use brackets `[]` after an object to call its index. We should also note that indexing **starts at 0** for Python.

# %%
name = 'Emma'
name
# Out:
# 'Emma'

# %%
name[0]
# Out:
# 'E'

# %%
name[1]
# Out:
# 'm'

# %%
name[-1]
# Out:
# 'a'

# %% [markdown]
# # String Indexing 2/3

# %%
name[:2]
# Out:
# 'Em'

# %%
name[2:]
# Out:
# 'ma'

# %%
name[::1]
# Out:
# 'Emma'

# %% [markdown]
# # String Indexing 3/3

# %%
name[::2]
# Out:
# 'Em'

# %% [markdown]
# What will be the ouptut of `name[::-1]`

# %% [markdown]
# # String Properties 1/2
#
# String are **immutable** i.e., once a string is created, the elements within it can not be changed or replaced.

# %%
name
# Out:
# 'Emma'

# %%
name[0] = 'e'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 name[0] = 'e'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # String Properties 2/2
#
# So if we need to chane the value of a string, we need to **reassign**:

# %%
name = name + " Stone"
name
# Out:
# 'Emma Stone'

# %%
name * 5
# Out:
# 'Emma StoneEmma StoneEmma StoneEmma StoneEmma Stone'

# %% [markdown]
# # Bulit-in String Method
#
# In Python, we can call objects' methods with a period and then the method name in the following form: `object.method(parameters)`. And here are some built-in methods in strings:

# %%
name.upper() # Convert to upper case
# Out:
# 'EMMA STONE'

# %%
name.lower() # Convert to lower case
# Out:
# 'emma stone'

# %%
name.split()  # Split by a separator (the default are white spaces)
# Out:
# ['Emma', 'Stone']

# %%
name.replace("m", "M")
# Out:
# 'EMMa Stone'

# %%
print("Thank you!")
# Out:
# Thank you!
