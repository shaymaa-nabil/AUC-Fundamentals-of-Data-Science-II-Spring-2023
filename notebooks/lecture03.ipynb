# %%
from IPython.display import display, Image
display(Image(filename="images/AUC.png"))

# %% [markdown]
# # Lists in Python
#
# - Slides by [Ahmed Moustafa](https://github.com/ahmedmoustafa)
# - Content modified from [Pierian Data](https://github.com/Pierian-Data/Complete-Python-3-Bootcamp)

# %% [markdown]
# # Git & GitHub Quick Review
#
# - What is Git? What is it used for?
# - What are the different components of the Git system?
# - What are the function of the following commands, `commit`, `pull`, and `push`?
# - On GitHub, what does **fork** do?
# - On GitHub, what does **pull request** do?

# %% [markdown]
# # Lists
#
# - Lists can be thought of the most general version of a sequence in Python.
#
# - Unlike strings, they are **mutable**, i.e. elements inside a list can be changed.
#
# - Lists are constructed with brackets `[ ]` and commas `,` separating every element in the list.

# %% [markdown]
# # Creating a List

# %%
weights = [65.0, 70.5, 72.3, 68.0, 77.2] # list of numbers
weights
# Out:
# [65.0, 70.5, 72.3, 68.0, 77.2]

# %%
cities = ["London", "Paris", "New York", "Tokyo", "Berlin"] # list of strings
cities
# Out:
# ['London', 'Paris', 'New York', 'Tokyo', 'Berlin']

# %%
types = [1, 2.5, "hello", "world", 42, "python"] # list of different data types
types
# Out:
# [1, 2.5, 'hello', 'world', 42, 'python']

# %% [markdown]
# # List of Lists
#
# We can also create a list of lists. For example, combining the two list we just created, `cities` and `weights` into a new list `my_list`:

# %%
my_list = [cities, weights]
my_list
# Out:
# [['London', 'Paris', 'New York', 'Tokyo', 'Berlin'],
#  [65.0, 70.5, 72.3, 68.0, 77.2]]

# %%
len(my_list)
# Out:
# 2

# %% [markdown]
# # Indexing and Slicing 1/3
#
# Indexing and slicing work just like in strings:

# %%
cities[0]
# Out:
# 'London'

# %%
cities[1:]
# Out:
# ['Paris', 'New York', 'Tokyo', 'Berlin']

# %%
cities[::-1]
# Out:
# ['Berlin', 'Tokyo', 'New York', 'Paris', 'London']

# %%
cities + ["Cairo", "Alexandria"]
# Out:
# ['London', 'Paris', 'New York', 'Tokyo', 'Berlin', 'Cairo', 'Alexandria']

# %% [markdown]
# # Indexing and Slicing 2/3

# %%
cities
# Out:
# ['London', 'Paris', 'New York', 'Tokyo', 'Berlin']

# %%
cities += ["Cairo", "Alexandria"]
cities
# Out:
# ['London', 'Paris', 'New York', 'Tokyo', 'Berlin', 'Cairo', 'Alexandria']

# %%
cities * 2
# Out:
# ['London',
#  'Paris',
#  'New York',
#  'Tokyo',
#  'Berlin',
#  'Cairo',
#  'Alexandria',
#  'London',
#  'Paris',
#  'New York',
#  'Tokyo',
#  'Berlin',
#  'Cairo',
#  'Alexandria']

# %% [markdown]
# # Indexing and Slicing 3/3

# %%
my_list
# Out:
# [['London', 'Paris', 'New York', 'Tokyo', 'Berlin', 'Cairo', 'Alexandria'],
#  [65.0, 70.5, 72.3, 68.0, 77.2]]

# %%
len(my_list)
# Out:
# 2

# %%
my_list[0]
# Out:
# ['London', 'Paris', 'New York', 'Tokyo', 'Berlin', 'Cairo', 'Alexandria']

# %%
my_list[1][2]
# Out:
# 72.3

# %% [markdown]
# # List Methods: `append`
#
# The `append()` method adds an item to the end of the list

# %%
print(cities)
len(cities)
# Out:
# ['London', 'Paris', 'New York', 'Tokyo', 'Berlin', 'Cairo', 'Alexandria']
# 7

# %%
cities.append ("Aswan")
print(cities)
len(cities)
# Out:
# ['London', 'Paris', 'New York', 'Tokyo', 'Berlin', 'Cairo', 'Alexandria', 'Aswan']
# 8

# %% [markdown]
# # List Methods: `pop`
#
# The `pop()` method removes the item at the given index from the list and returns the removed item

# %%
cities.pop() # pop (remove) the last element
# Out:
# 'Aswan'

# %%
print(cities)
len(cities)
# Out:
# ['London', 'Paris', 'New York', 'Tokyo', 'Berlin', 'Cairo', 'Alexandria']
# 7

# %%
cities.pop(1) # pop (remove) at the given index
# Out:
# 'Paris'

# %%
print(cities)
len(cities)
# Out:
# ['London', 'New York', 'Tokyo', 'Berlin', 'Cairo', 'Alexandria']
# 6

# %% [markdown]
# # List Methods: `reverse`
#
# The `reverse()` method reverses the elements of the list

# %%
print ("Before: ", cities)
# Out:
# Before:  ['London', 'New York', 'Tokyo', 'Berlin', 'Cairo', 'Alexandria']

# %%
cities.reverse()

# %%
print ("After: ", cities)
# Out:
# After:  ['Alexandria', 'Cairo', 'Berlin', 'Tokyo', 'New York', 'London']

# %% [markdown]
# # List Methods: `sort`
#
# The `sort()` method sorts the items of a list in ascending or descending order

# %%
cities.sort()
cities
# Out:
# ['Alexandria', 'Berlin', 'Cairo', 'London', 'New York', 'Tokyo']

# %% [markdown]
# # List Methods: `index`
#
# The `index()` method returns the index of the specified element in the list

# %%
cities.index("Tokyo")
# Out:
# 5

# %%
# cities.index("Dubai")

# %% [markdown]
# # Lists Exercise
#
# GitHub Classroom Assignment [https://classroom.github.com/a/a24f_RDP](https://classroom.github.com/a/a24f_RDP)

# %%
from IPython.display import display, Image
display(Image(filename="images/lecture3_lists_exercise.png", width = 300))

# %% [markdown]
# # Dictionaries
#
# Dictionaries in Python is a form of mapping, between keys and their corresponding value

# %% [markdown]
# # Constructing a Dictionary

# %%
my_dict = {'key1':'value1','key2':'value2'} # Make a dictionary with {} and : to signify a key and a value
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_dict['key2'] # Call values by their key
# Out:
# 'value2'

# %%
my_dict = {'key1':123,'key2':[12,23,33],'key3':['item0','item1','item2']} #dictionaries are very flexible
my_dict['key3']
# Out:
# ['item0', 'item1', 'item2']

# %% [markdown]
# # Dictionary Methods

# %%
d = {'key1':1,'key2':2,'key3':3} # Create a typical dictionary
d
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3}

# %%
d.keys() # Method to return a list of all keys
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
d.values() # Method to grab all values
# Out:
# dict_values([1, 2, 3])

# %%
d.items() # Method to return tuples of all items  (we'll learn about tuples soon)
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3)])
