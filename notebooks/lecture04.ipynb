# %%
from IPython.display import display, Image
display(Image(filename="images/AUC.png"))

# %% [markdown]
# # Control Flow in Python
#
# [Ahmed Moustafa](https://github.com/ahmedmoustafa)

# %%
from IPython.display import display, Image
display(Image(filename="images/attendance-qr-code-Feb16.png", width = 400))

# %% [markdown]
# # Definition of Control Flow
#
# - Control flow is the order in which statements and instructions are executed in a program
# - Control flow can be affected by decision-making statements, loops, and function calls.

# %%
from IPython.display import display, Image
display(Image(filename="images/control-flow.png", width = 400))
